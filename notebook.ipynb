# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
df = pd.read_excel('Input.xlsx')
df
# Out:
#              URL_ID                                                URL
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
# [100 rows x 2 columns]

# %%
df['URL'].iloc[1]
# Out:
# 'https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/'

# %%
URL = df['URL'].iloc[0]
r = requests.get(URL) 
print(r.content)
# Out:
# b'<!doctype html >\r\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\r\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->\r\n<head>\r\n    <title>Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights</title>\r\n    <meta charset="UTF-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <link rel="pingback" href="https://insights.blackcoffer.com/xmlrpc.php" />\r\n    <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v21.1 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<link rel="canonical" href="https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/" />\n\t<meta property="og:loc
# ...

# %%
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://insights.blackcoffer.com/xmlrpc.php" rel="pingback"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <!-- This site is optimized with the Yoast SEO plugin v21.1 - https://yoast.com/wordpress/plugins/seo/ -->
#   <link href="https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/" rel="canonical"/>
# ...

# %%
data = soup.find('div',class_ = "td-post-content tagdiv-type").get_text()
data
# Out:
# '\n        \nWe have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.\n\n\n\nRising IT cities\n\n\n\n\nNoida:- Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an information technology hub.\n\n\n\nGurgaon:- Gurgaon in Haryana is also an emerging IT hub. Many larg
# ...

# %%
reviews_selector = soup.find('div',class_="td-full-screen-header-image-wrap").get_text()
reviews_selector+=data
print(reviews_selector)
# Out:
#
#             Home  What We Think  Rising IT cities and its impact on the economy, environment, infrastructure, and...
#
#
#
#
#
#
#
# 	                    EntertainmentBroadcastingFutureForecastsWhat We ThinkFuturist	                    Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.
#
#
#
# 	                        By Ajay Bidyarthy -  	                        August 24, 2023	                        2850
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
s = reviews_selector.split("\n")
s
# Out:
# ['',
#  '',
#  '        ',
#  '            Home  What We Think  Rising IT cities and its impact on the economy, environment, infrastructure, and...',
#  '',
#  '\t        ',
#  '',
#  '\t\t        ',
#  '',
#  '\t                ',
#  '',
#  '\t                    EntertainmentBroadcastingFutureForecastsWhat We ThinkFuturist\t                    Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.',
#  '',
#  '\t                    ',
#  '\t                    ',
#  '\t                        By Ajay Bidyarthy -  \t                        August 24, 2023\t                        2850\t                        \t                    ',
#  '',
#  '\t                ',
#  '',
#  '\t\t            ',
#  '\t\t        ',
#  '            ',
#  '',
#  '        ',
#  '',
#  '        ',
#  '            ',
#  '        ',
#  '    ',
#  '        ',
# ...

# %%
"""for x in s :
    if x =='' or x=='\t':
        s.remove(x)
s"""
# Out:
# "for x in s :\n    if x =='' or x=='\t':\n        s.remove(x)\ns"

# %%
filtered_list = list(filter(lambda x: x.strip() != '', s))

# Remove '\t' from each string
filtered_list = [s.replace('\t', '') for s in filtered_list]

print(filtered_list)
# Out:
# ['            Home  What We Think  Rising IT cities and its impact on the economy, environment, infrastructure, and...', '                    EntertainmentBroadcastingFutureForecastsWhat We ThinkFuturist                    Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.', '                        By Ajay Bidyarthy -                          August 24, 2023                        2850                                            ', 'We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.', '
# ...

# %%
for x in filtered_list:
    print(x)
# Out:
#             Home  What We Think  Rising IT cities and its impact on the economy, environment, infrastructure, and...
#                     EntertainmentBroadcastingFutureForecastsWhat We ThinkFuturist                    Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.
#                         By Ajay Bidyarthy -                          August 24, 2023                        2850
# We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.
# Rising IT cities
# ...

# %%
filtered_list = [s.strip().replace('\t', '').replace('  ', ' ') for s in filtered_list if s.strip() != '']

print(filtered_list)
# Out:
# ['Home What We Think Rising IT cities and its impact on the economy, environment, infrastructure, and...', 'EntertainmentBroadcastingFutureForecastsWhat We ThinkFuturist          Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.', 'By Ajay Bidyarthy -             August 24, 2023            2850', 'We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.', 'Rising IT cities', 'Noida:- Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microso
# ...

# %%
text = '\n'.join(filtered_list)

print(text)
# Out:
# Home What We Think Rising IT cities and its impact on the economy, environment, infrastructure, and...
# EntertainmentBroadcastingFutureForecastsWhat We ThinkFuturist          Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.
# By Ajay Bidyarthy -             August 24, 2023            2850
# We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.
# Rising IT cities
# ...

# %%
import os

folder_path = 'StopWords'  # Replace with your folder path

# Get a list of all files in the folder
all_files = os.listdir(folder_path)

# Filter out only the files (not directories)
file_paths = [os.path.join(folder_path, file) for file in all_files if os.path.isfile(os.path.join(folder_path, file))]

# Print the file paths
for file_path in file_paths:
    print(file_path)
# Out:
# StopWords\StopWords_Auditor.txt
# StopWords\StopWords_Currencies.txt
# StopWords\StopWords_DatesandNumbers.txt
# StopWords\StopWords_Generic.txt
# StopWords\StopWords_GenericLong.txt
# StopWords\StopWords_Geographic.txt
# StopWords\StopWords_Names.txt

# %%
all_stop_words=set()
for file_path in file_paths:
    with open(file_path, 'r') as file:
        stop_words = set(word.strip() for word in file.readlines())
        for x in stop_words:
            all_stop_words.add(x)
print(all_stop_words)
# Out:
# {'ADELE', 'VARGO', 'VANESA', 'CARLI', 'BRANDENBURG', 'DEONNA', 'FAVELA', 'ALETA', 'every', 'MARQUERITE', 'MOUNTAIN', 'CROUCH', 'RATHBUN', 'HYMAN', 'HALLORAN', 'AIMEE', 'ADELLA', 'BENAVIDEZ', 'JAIMES', 'ANALISA', 'LERA', 'RIVERA', 'BRANT', 'JESSUP', 'IRENA', 'LEMKE', 'less', 'MELANIE', 'BRISCOE', 'OXFORD', 'DELEON', 'COLELLA', 'BUCHANAN', 'MCKENZIE', 'VEOLA', 'SWINNEY', 'DANNETTE', 'PETRINA', 'WILLSON', 'GERTRUDE', 'MONICA', 'CASWELL', 'DOOLITTLE', 'BOBBIE', 'ERINN', 'HITCHCOCK', 'LITTRELL', 'MARSTON', 'BOK', 'FERRARI', 'RUSHING', 'BIRGIT', 'LEJEUNE', 'LANIE', 'RATCLIFFE', 'BAER', 'MARIBEL', 'off', 'MARLEEN', 'QUINTON', 'LEONORA', 'NEIDA', 'CARMELA', 'COLBURN', 'WASHINGTON', 'MARQUETTA', 'BULA', 'FRAGA', 'OGLE', 'CESAR', 'PHUONG', 'PEARLE', 'GRAYCE', 'ARMSTRONG', 'WYSOCKI', 'RADCLIFF', 'KATHY', 'MCADOO', 'HAZELWOOD', 'ENGLAND', 'QUINONEZ', 'THERIAULT', 'TATRO', 'HILLMAN', 'LEATHERS', 'PADRON', 'CASSONDRA', 'GUSSIE', 'MATTISON', 'HAKE', 'TOMI', 'PRESLEY', 'TAI', 'OCT', 'NUEVO SOL | Per
# ...

# %%
words = text.split()
cleaned_words = [word for word in words if word.lower() not in all_stop_words]
cleaned_text = ' '.join(cleaned_words)
print(cleaned_text)
# Out:
# Home Rising cities impact economy, environment, infrastructure, and... EntertainmentBroadcastingFutureForecastsWhat ThinkFuturist Rising cities impact economy, environment, infrastructure, city life year 2040. Ajay Bidyarthy - August 24, 2023 2850 huge development dependence people technology recent years. development AI ChatGPT recent years. normal thing fully dependent technology 2040. Information technology major power developing nations. member developing nation, India rapidly growing base. grown cities major control centres Information technology 2040. Rising cities Noida:- Noida Uttar Pradesh Delhi emerging sector now. large companies Google, Microsoft, IBM, Infosys set companies here. Noida market base billions dollars great job boosting national economy. establishment software companies made Noida information technology hub. Gurgaon:- Gurgaon Haryana emerging hub. large companies Google, Microsoft, IBM, Infosys set companies here. Gurgaon market base billions dollars great jo
# ...

# %%
folder_path = 'MasterDictionary'  # Replace with your folder path

# Get a list of all files in the folder
all_files = os.listdir(folder_path)

# Filter out only the files (not directories)
file_paths = [os.path.join(folder_path, file) for file in all_files if os.path.isfile(os.path.join(folder_path, file))]

# %%
positive = set()
negative = set()
for file_path in file_paths:
    
    if file_path == 'MasterDictionary\positive-words.txt':
        
        with open(file_path, 'r') as file:
            positive = set(word.strip() for word in file.readlines())
    else :
        with open(file_path, 'r') as file:
            negative  = set(word.strip() for word in file.readlines())
print(positive)
print(negative)
# Out:
# {'prodigiously', 'woo', 'revolutionized', 'astoundingly', 'prowess', 'prompt', 'abundant', 'achievible', 'striking', 'brilliant', 'empathize', 'pepped', 'indebted', 'godlike', 'helped', 'spectacular', 'splendidly', 'spontaneous', 'responsive', 'trendy', 'tranquility', 'law-abiding', 'prudent', 'pinnacle', 'thrifty', 'perfectly', 'vivacious', 'angel', 'proven', 'soundly', 'intelligent', 'easing', 'contrasty', 'gallant', 'accolade', 'exonerate', 'simpler', 'paradise', 'favorited', 'irreplaceable', 'zenith', 'modesty', 'cost-saving', 'refunded', 'yay', 'consistent', 'masters', 'unfazed', 'fun', 'impartially', 'flatteringly', 'ingenuity', 'trustworthiness', 'geekier', 'affordably', 'slick', 'agile', 'uphold', 'pretty', 'pros', 'piety', 'amply', 'flawlessly', 'brighter', 'reaffirmation', 'gladness', 'appreciable', 'respectful', 'survivor', 'steadfastly', 'providence', 'accommodative', 'believeable', 'sharp', 'proving', 'quiet', 'smart', 'sexy', 'exhilarate', 'honoring', 'advanced', 'agree
# ...

# %%
import nltk

# Download NLTK data if not already installed
nltk.download('punkt')

tokens = nltk.word_tokenize(cleaned_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\paritosh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(tokens)
# Out:
# ['Home', 'Rising', 'cities', 'impact', 'economy', ',', 'environment', ',', 'infrastructure', ',', 'and', '...', 'EntertainmentBroadcastingFutureForecastsWhat', 'ThinkFuturist', 'Rising', 'cities', 'impact', 'economy', ',', 'environment', ',', 'infrastructure', ',', 'city', 'life', 'year', '2040', '.', 'Ajay', 'Bidyarthy', '-', 'August', '24', ',', '2023', '2850', 'huge', 'development', 'dependence', 'people', 'technology', 'recent', 'years', '.', 'development', 'AI', 'ChatGPT', 'recent', 'years', '.', 'normal', 'thing', 'fully', 'dependent', 'technology', '2040', '.', 'Information', 'technology', 'major', 'power', 'developing', 'nations', '.', 'member', 'developing', 'nation', ',', 'India', 'rapidly', 'growing', 'base', '.', 'grown', 'cities', 'major', 'control', 'centres', 'Information', 'technology', '2040', '.', 'Rising', 'cities', 'Noida', ':', '-', 'Noida', 'Uttar', 'Pradesh', 'Delhi', 'emerging', 'sector', 'now', '.', 'large', 'companies', 'Google', ',', 'Microsoft', ',', 'IBM'
# ...

# %%
positive_score , negative_score = 0 ,0
for word in tokens :
    if word in positive :
        positive_score += 1
    elif word in negative :
        negative_score += 1
print(positive_score,negative_score)
# Out:
# 33 5

# %%
polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
print(polarity_score)
# Out:
# 0.7368420858725767

# %%
subjectivity_score = (positive_score + negative_score) / (len(tokens) + 0.000001)
print(subjectivity_score)
# Out:
# 0.05019815052813983

# %%
sentences = nltk.sent_tokenize(text)
average_sentence_length = len(tokens) / len(sentences)
print(average_sentence_length)
# Out:
# 9.582278481012658

# %%
pip install syllables
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\python\python39\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.
# ...

# %%
"""import syllables
complex_words = [word for word in tokens if syllables.estimate(word) > 2]
percentage_complex_words = len(complex_words) / len(tokens) * 100
fog_index = 0.4 * (average_sentence_length + percentage_complex_words)

# ...

# Syllable Count Per Word
syllable_count_per_word = [syllables.estimate(word) for word in tokens]
"""
# ...
# Out:
# 'import syllables\ncomplex_words = [word for word in tokens if syllables.estimate(word) > 2]\npercentage_complex_words = len(complex_words) / len(tokens) * 100\nfog_index = 0.4 * (average_sentence_length + percentage_complex_words)\n\n# ...\n\n# Syllable Count Per Word\nsyllable_count_per_word = [syllables.estimate(word) for word in tokens]\n'

# %%
"""from nltk.corpus import cmudict

# Download NLTK data if not already installed
nltk.download('punkt')
nltk.download('cmudict')

# Function to count syllables using NLTK's CMU Pronouncing Dictionary
def syllable_count(word):
    d = cmudict.dict()

    # If word is in the CMU Pronouncing Dictionary
    if word.lower() in d:
        pronunciation = d[word.lower()][0]

        # Counting syllables with exceptions for words ending in "es" or "ed"
        count = len([1 for i in range(len(pronunciation)) if pronunciation[i][-1].isdigit() and not (i > 0 and pronunciation[i - 1] in ['EY1', 'IH0'])])
        return count

    # If word is not in the CMU Pronouncing Dictionary
    return 0
syllable_count_per_word = [syllable_count(word) for word in tokens]
print(syllable_count_per_word)"""
# Out:
# 'from nltk.corpus import cmudict\n\n# Download NLTK data if not already installed\nnltk.download(\'punkt\')\nnltk.download(\'cmudict\')\n\n# Function to count syllables using NLTK\'s CMU Pronouncing Dictionary\ndef syllable_count(word):\n    d = cmudict.dict()\n\n    # If word is in the CMU Pronouncing Dictionary\n    if word.lower() in d:\n        pronunciation = d[word.lower()][0]\n\n        # Counting syllables with exceptions for words ending in "es" or "ed"\n        count = len([1 for i in range(len(pronunciation)) if pronunciation[i][-1].isdigit() and not (i > 0 and pronunciation[i - 1] in [\'EY1\', \'IH0\'])])\n        return count\n\n    # If word is not in the CMU Pronouncing Dictionary\n    return 0\nsyllable_count_per_word = [syllable_count(word) for word in tokens]\nprint(syllable_count_per_word)'

# %%
"""def simple_syllable_count(word):
    vowels = "aeiouyAEIOUY"
    count = sum(1 for char in word if char in vowels)
    return count
syllable_count_per_word = [syllable_count(word) for word in tokens]
print(syllable_count_per_word)"""
# Out:
# 'def simple_syllable_count(word):\n    vowels = "aeiouyAEIOUY"\n    count = sum(1 for char in word if char in vowels)\n    return count\nsyllable_count_per_word = [syllable_count(word) for word in tokens]\nprint(syllable_count_per_word)'

# %%
personal_pronouns = ["I", "we", "my", "ours", "us"] 
personal_pronoun_count = sum(1 for word in tokens if word.lower() in personal_pronouns)
print(personal_pronoun_count)
# Out:
# 0

# %%
word_count = len(tokens)
average_word_length = sum(len(word) for word in tokens) / word_count
print(average_sentence_length)
# Out:
# 9.582278481012658

# %%
df.iloc[13]
# Out:
# URL_ID                                      blackassign0014
# URL       https://insights.blackcoffer.com/rise-of-e-hea...
# Name: 13, dtype: object

# %%
df = pd.read_excel('Output Data Structure.xlsx')
df
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#     POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# ...

# %%
len(df)
# Out:
# 100
